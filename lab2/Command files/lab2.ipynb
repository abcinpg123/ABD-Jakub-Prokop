# %%
import pandas as pd

tb = pd.read_csv("../Original data/tb.csv")

cols = tb.columns
# tb = tb.dropna(axis=1, how='all', subset=cols[2:])
tb.head(10)
# Out:
#   iso2  year  new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 0   AD  1989     NaN         NaN          NaN          NaN           NaN
# 1   AD  1990     NaN         NaN          NaN          NaN           NaN
# 2   AD  1991     NaN         NaN          NaN          NaN           NaN
# 3   AD  1992     NaN         NaN          NaN          NaN           NaN
# 4   AD  1993    15.0         NaN          NaN          NaN           NaN
# 5   AD  1994    24.0         NaN          NaN          NaN           NaN
# 6   AD  1996     8.0         NaN          NaN          0.0           0.0
# 7   AD  1997    17.0         NaN          NaN          0.0           0.0
# 8   AD  1998     1.0         NaN          NaN          0.0           0.0
# 9   AD  1999     4.0         NaN          NaN          0.0           0.0
#
#    new_sp_m2534  new_sp_m3544  new_sp_m4554  ...  new_sp_f04  new_sp_f514  \
# 0           NaN           NaN           NaN  ...         NaN          NaN
# ...

# %%
new_cols = []
for col in tb.columns[3:]:
    string = col.split('_')[2]
    sex = ""
    age = ""

    if string[0]=='m':
        sex += "Male"
    elif string[0]=='f':
        sex += "Female"

    age = string[1:]
    print(age)
    if len(age) == 2:
        age = age[0] + '-' + age[1]
    elif len(age) == 3:
        age = age[0] + '-' + age[1:2]
    elif len(age) == 4:
        age = age[0:2] + '-' + age[2:3] 
    elif age == "u":
        age = "age_unknown"

    new_cols.append(sex + ' ' + age)
print(new_cols)

tb.head(10)
# Out:
# 04
# 514
# 014
# 1524
# 2534
# 3544
# 4554
# 5564
# 65
# u
# 04
# 514
# 014
# 1524
# 2534
# 3544
# 4554
# 5564
# 65
# u
# ['Male 0-4', 'Male 5-1', 'Male 0-1', 'Male 15-2', 'Male 25-3', 'Male 35-4', 'Male 45-5', 'Male 55-6', 'Male 6-5', 'Male age_unknown', 'Female 0-4', 'Female 5-1', 'Female 0-1', 'Female 15-2', 'Female 25-3', 'Female 35-4', 'Female 45-5', 'Female 55-6', 'Female 6-5', 'Female age_unknown']
#   iso2  year  new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 0   AD  1989     NaN         NaN          NaN          NaN           NaN
# 1   AD  1990     NaN         NaN          NaN          NaN           NaN
# 2   AD  1991     NaN         NaN          NaN          NaN           NaN
# 3   AD  1992     NaN         NaN          NaN          NaN           NaN
# 4   AD  1993    15.0         NaN          NaN          NaN           NaN
# 5   AD  1994    24.0         NaN          NaN          NaN           NaN
# ...
